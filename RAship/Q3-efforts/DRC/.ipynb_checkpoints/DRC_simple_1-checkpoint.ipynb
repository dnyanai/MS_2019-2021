# %%
import pandas as pd
import sklearn as sk
from nltk.corpus import stopwords

# %%
df = pd.read_csv('DRC_Data.csv',encoding='latin-1',index_col='id')
df.head()
# Out:
#                 in_swahili in_lingala in_kikongo   in_kinyarwanda  \
# id
# 1                   Mukula        NaN         NaN             NaN
# 2                      NaN        NaN         NaN             NaN
# 3   Mukuyakuya/Bakuyakuya       Bauta         NaN             NaN
# 4                    Imbua        NaN         NaN             NaN
# 5                 Inyenzi         NaN         NaN             NaN
#
#             in_french                       alternative_words_references  \
# id
# 1   Mangeur de chiens                          Congolese, Luba, Kasaïen
# 2        Genocidaire                                  Rwandais,Congolese
# 3                 NaN  nukundugulu, nzenza, djajambu, ba kuya kuya, m...
# 4               chien  Mbua, mbwa, ba imbwa, ibwa, umbwa, muluba mbua...
# 5                 NaN                       Inkotanyi, Tutsi, Congolese
#
#                                      regional_meaning                 tags  \
# id
# ...

# %%
df.isnull().sum()
# Out:
# in_swahili                      28
# in_lingala                      48
# in_kikongo                      49
#  in_kinyarwanda                 48
# in_french                       40
# alternative_words_references    37
# regional_meaning                29
# tags                            31
# context                         32
# common_phrases                  37
# action_scenario                 43
# sample_post                     34
# english_translation             35
# social_media_#                  36
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 14 columns):
# in_swahili                      22 non-null object
# in_lingala                      2 non-null object
# in_kikongo                      1 non-null object
#  in_kinyarwanda                 2 non-null object
# in_french                       10 non-null object
# alternative_words_references    13 non-null object
# regional_meaning                21 non-null object
# tags                            19 non-null object
# context                         18 non-null object
# common_phrases                  13 non-null object
# action_scenario                 7 non-null object
# sample_post                     16 non-null object
# english_translation             15 non-null object
# social_media_#                  14 non-null object
# dtypes: object(14)
# memory usage: 5.9+ KB

# %%
df.describe()
# Out:
#                  in_swahili in_lingala in_kikongo       in_kinyarwanda  \
# count                    22          2           1                   2
# unique                   22          2           1                   2
# top     Inkotanyi/Ingotanyi       Noko      Nwagsi  Kichuchu/bichuchu
# freq                      1          1           1                   1
#
#                 in_french                       alternative_words_references  \
# count                  10                                                 13
# unique                 10                                                 13
# top     Mangeur de chiens   Munyamulenge, Rwandophones, Tutsi, Hutu, Mulu...
# freq                    1                                                  1
#
#                                          regional_meaning        tags  \
# count                                                  21          19
# unique                                                 21          14
# ...

# %%
df.fillna('NA',inplace=True)
