# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns',50)
pd.options.display.max_rows
# Out:
# 60

# %%
a = pd.read_csv('listings.csv')
a.head(1)
# Out:
#     id                       listing_url       scrape_id last_scraped  \
# 0  109  https://www.airbnb.com/rooms/109  20190708161040   2019-07-09
#
#                                                 name  \
# 0  Amazing bright elegant condo park front *UPGRA...
#
#                                              summary  \
# 0  *** Unit upgraded with new bamboo flooring, br...
#
#                                                space  \
# 0  *** Unit upgraded with new bamboo flooring, br...
#
#                                          description experiences_offered  \
# 0  *** Unit upgraded with new bamboo flooring, br...                none
#
#   neighborhood_overview notes transit access interaction  \
# 0                   NaN   NaN     NaN    NaN         NaN
#
#                                          house_rules  thumbnail_url  \
# 0  Camelot NEW RESIDENTS’ GENERAL INFORMATION   F...            NaN
#
#    medium_url                                        picture_url  \
# ...

# %%
lst = ['listing_url','scrape_id','last_scraped','summary',\
       'space','description','experiences_offered','neighborhood_overview','interaction','access','house_rules',\
       'notes','thumbnail_url','medium_url','picture_url','host_url',\
      'host_about','host_response_rate','host_acceptance_rate','host_thumbnail_url','host_picture_url',\
       'host_listings_count','host_has_profile_pic','host_verifications','host_neighbourhood',\
       'neighbourhood_cleansed','neighbourhood_group_cleansed','market','smart_location','country_code',\
      'country','is_location_exact','square_feet','weekly_price','monthly_price','minimum_minimum_nights',\
      'minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights',\
      'minimum_nights_avg_ntm','maximum_nights_avg_ntm','calendar_updated','has_availability','calendar_last_scraped',\
      'availability_30','availability_60','availability_90','availability_365','number_of_reviews_ltm',\
       'requires_license','license','jurisdiction_names','is_business_travel_ready','require_guest_profile_picture',\
      'require_guest_phone_verification','calculated_host_listings_count','calculated_host_listings_count_entire_homes',\
      'calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms','xl_picture_url',\
      ]
a.drop(columns=lst,inplace=True)

# %%
a.shape
# Out:
# (44620, 46)

# %%
df = a.copy()

# %%
df['colid'] = df.index

# %%
df.head(2)
df.drop('id',axis=1,inplace=True)

# %%
#df1 = df[['id','colid']].copy()
#.reset_index(drop=True,inplace=True)
df.rename(columns={'colid':'id'},inplace=True)

# %%
df.id +=1

# %%
df.set_index('id',inplace=True)
df.head(1)
# Out:
#                                                  name transit  host_id  \
# id
# 1   Amazing bright elegant condo park front *UPGRA...     NaN      521
#
#    host_name  host_since                             host_location  \
# id
# 1      Paolo  2008-06-27  San Francisco, California, United States
#
#    host_response_time host_is_superhost  host_total_listings_count  \
# id
# 1                 NaN                 f                        1.0
#
#    host_identity_verified                          street neighbourhood  \
# id
# 1                       t  Culver City, CA, United States   Culver City
#
#            city state zipcode  latitude  longitude property_type  \
# id
# 1   Culver City    CA   90230  33.98209 -118.38494   Condominium
#
#           room_type  accommodates  bathrooms  bedrooms  beds  bed_type  \
# id
# 1   Entire home/apt             6        2.0       2.0   3.0  Real Bed
#
#                                             amenities    price  \
# id
# ...

# %%
df.shape
# Out:
# (44620, 45)

# %%
df1 = df.copy()

# %% [markdown]
# ## Cleaning the city column & state column

# %%
#df.rename(index={'Afghanistan':'Afghanistan_renamed'})
df1.state.loc[df1.state=='California'] = 'CA'
df1.state.unique()
df1.state = df1['state'].str.upper()

# %%
df1.state.value_counts()
# Out:
# CA    44611
# NY        2
# 加州        2
# IL        1
# 加洲        1
# FL        1
# Name: state, dtype: int64

# %%
#df[~(df.state=='CA')].drop
#df1.drop(df1[(df1['Year'].values==1970)].index,axis=0,inplace=True)
#a = df.state[~(df.state=='CA')]
df1.drop(df1[~(df1.state.values=='CA')].index,axis=0,inplace=True)

# %%
#df.groupby('host_location')['city'].unique()
df1.city = df1.city.str.lower()

#df1.city.loc[df1.city=='n hollywood'] = 'north hollywood'
#df1.city.loc[df1.city=='granada hills, (los angeles)'] = 'granada hills'

df1.city.unique()
#df.loc[df.city=='venice'].groupby('neighbourhood')['street'].value_counts()
df1.city.dropna(inplace=True)
## Contains checks for anything which contains venice and not just venice 
df1.city[df1.city.str.contains('venice')==True].value_counts()
df1.city.loc[df1.city.str.contains('venice')] = 'los angeles'
df1.city.unique()
# Out:
# array(['culver city', 'burbank', 'los angeles', 'santa monica',
#        'bellflower', 'woodland hills', 'beverly hills', 'long beach',
#        'redondo beach', 'torrance', 'n hollywood', 'studio city',
#        'glendale', 'malibu', 'san fernando valley', 'lynwood',
#        'hollywood', 'granada hills, (los angeles)', 'west hollywood',
#        'encino', 'north hills', 'carson', 'north hollywood', 'altadena',
#        'calabasas', 'hollywood hills', 'agoura hills-malibu',
#        'manhattan beach', 'sherman oaks', 'topanga',
#        'rancho palos verdes', 'san gabriel', 'marina del rey', 'lakewood',
#        'topanga canyon', 'sierra madre', 'pasadena', 'agua dulce',
#        'hermosa beach', 'compton', 'pacific palisades', 'el segundo',
#        'los angeles county', 'inglewood', 'covina', 'rowland heights',
#        'south pasadena', 'la cañada flintridge', 'montrose', 'walnut',
#        'playa del rey', 'whittier', 'littlerock', 'alhambra',
# ...

# %%
df1.groupby('city')['neighbourhood'].value_counts()
# Out:
# city                          neighbourhood
#                               Monterey Park                    2
#                               West Covina                      2
#                               El Monte                         1
#                               Rosemead                         1
#                               Temple City                      1
#                                                               ..
# woodland hills                Woodland Hills/Warner Center    12
# woodland hills (los angeles)  Woodland Hills/Warner Center     1
# woodland hills, los angeles   Woodland Hills/Warner Center     1
# woodland hills/los angeles    Woodland Hills/Warner Center     1
# woodland hls                  Woodland Hills/Warner Center     1
# Name: neighbourhood, Length: 627, dtype: int64

# %%
df1['city'] = df1['city'].str.replace(r'[^\x00-\x7F]+', '')
df1.city.dropna(inplace=True)
df1.city.value_counts()
# Out:
# los angeles                        28339
# long beach                          1612
# santa monica                        1059
# west hollywood                       973
# beverly hills                        767
#                                    ...
# canoga park                            1
# los angeles/burbank/toluca lake        1
# rowland heigh                          1
# los angels                             1
# covina hills                           1
# Name: city, Length: 323, dtype: int64

# %%
df1.city[df1.city.str.contains('los angeles')==True].value_counts()
df1.groupby
#df.city.loc[df.city.str.contains('los angeles')] = 'los angeles'
#df.city.unique()
# Out:
# <bound method NDFrame.groupby of                                                     name  \
# id
# 1      Amazing bright elegant condo park front *UPGRA...
# 2                      Family perfect;Pool;Near Studios!
# 3      Fireplace Mirrored Mini Suit (Website hidden b...
# 4                                  Zen Life at the Beach
# 5      *Upscale Professional Home with Beautiful Studio*
# ...                                                  ...
# 44616  Amazing private room and (Website hidden by Ai...
# 44617     Beach area! Furnished bedroom private bathroom
# 44618  Spanish Style Dream Vacation Mansion in Hearto...
# 44619     Beautiful Apartment The Heart Of Beverly Hills
# 44620    Private Room near LAX with Rentable Car & Pool!
#
#                                                  transit    host_id  \
# id
# 1                                                    NaN        521
# 2      Short drive to subway and elevated trains runn...        767
# ...

# %%
df1.shape
# Out:
# (44611, 45)

# %%
 df1.head()
# Out:
#                                                  name  \
# id
# 1   Amazing bright elegant condo park front *UPGRA...
# 2                   Family perfect;Pool;Near Studios!
# 3   Fireplace Mirrored Mini Suit (Website hidden b...
# 4                               Zen Life at the Beach
# 5   *Upscale Professional Home with Beautiful Studio*
#
#                                               transit  host_id  \
# id
# 1                                                 NaN      521
# 2   Short drive to subway and elevated trains runn...      767
# 3   There are many buses; bus stops going in every...     3008
# 4                                                 NaN     3041
# 5   Public transportation is a 3 minutes walk to t...     3207
#
#          host_name  host_since                             host_location  \
# id
# 1            Paolo  2008-06-27  San Francisco, California, United States
# 2          Melissa  2008-07-11        Burbank, California, United States
# ...

# %%
df1[df1.city=='los angeles'].value_counts()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-45-8b1976dfe020> in <module>
# ----> 1 df1[df1.city=='los angeles'].value_counts()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2969         # Do we have a (boolean) 1d indexer?
#    2970         if com.is_bool_indexer(key):
# -> 2971             return self._getitem_bool_array(key)
#    2972
#    2973         # We are left with two options: a single key, and a collection of keys,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3021         # check_bool_indexer will throw exception if Series key cannot
# ...
