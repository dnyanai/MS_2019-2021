# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',150)

# %%
df1 = pd.read_csv('./Registered_Business_Locations_-_San_Francisco.csv')

# %%
df1 = df1[(df1.City=='San Francisco')&(df1.State=='CA')]
print(df1['Street Address'].count())
df1.head()
# Out:
# 12071
#         Location Id  Business Account Number Ownership Name  \
# 5    1157686-08-171                  1074591       Alice Ho
# 17   1090504-08-161                  1043060     Lai Junwen
# 26   1142723-04-171                  1039498  Communion Inc
# 47   1125254-10-161                  1059484    Tian Qiyuan
# 205  1179680-02-181                  1083854          Famus
#
#               DBA Name      Street Address           City State  \
# 5          Little Kite        3515 20th St  San Francisco    CA
# 17   Chase Luck Bakery      1325 Ocean Ave  San Francisco    CA
# 26     Communion Juice  103 Horne Ave Bldg  San Francisco    CA
# 47               One +       166 Prague St  San Francisco    CA
# 205     Sultan's Kebab        3915 24th St  San Francisco    CA
#
#      Source Zipcode Business Start Date Business End Date Location Start Date  \
# 5           94110.0           8/10/2017        12/31/2018           8/10/2017
# 17          94112.0           8/18/2016        12/25/2016           8/18/2016
# 26          94124.0           7/13/2016          1/1/2017            4/1/2017
# 47          94112.0          10/12/2016         5/14/2019          10/26/2016
# 205         94114.0           2/20/2018         3/31/2019           2/20/2018
#
#     Location End Date Mail Address Mail City Mail Zipcode Mail State  \
# 5          12/31/2018          NaN       NaN          NaN        NaN
# 17         12/25/2016          NaN       NaN          NaN        NaN
# 26           1/1/2017          NaN       NaN          NaN        NaN
# 47          5/14/2019          NaN       NaN          NaN        NaN
# 205         3/31/2019          NaN       NaN          NaN        NaN
#
#     NAICS Code NAICS Code Description  Parking Tax  Transient Occupancy Tax  \
# 5    7220-7229          Food Services        False                    False
# 17   7220-7229          Food Services        False                    False
# 26   7220-7229          Food Services        False                    False
# 47   7220-7229          Food Services        False                    False
# 205  7220-7229          Food Services        False                    False
#
#     LIC Code LIC Code Description  Supervisor District  \
# 5        H26                  NaN                  NaN
# 17       NaN                  NaN                  NaN
# 26       NaN                  NaN                  NaN
# 47       H98                  NaN                  NaN
# 205      H24                  NaN                  NaN
#
#     Neighborhoods - Analysis Boundaries Business Corridor Business Location
# 5                                   NaN               NaN               NaN
# 17                                  NaN               NaN               NaN
# 26                                  NaN               NaN               NaN
# 47                                  NaN               NaN               NaN
# 205                                 NaN               NaN               NaN

# %%
lst = ['Location Id','Location Start Date','Location End Date','Mail Address',\
      'Mail City','Mail Zipcode','Mail State',]

# %%
df1.head()
df = df1['Street Address'].str.extract('(?P<Address_Number>\d+)(?P<Street_Address>.*)', expand=True)
#print (df)
df1['Address Number'] = df.Address_Number
df1['Street Address'] = df.Street_Address
df1['Street Address'] = df1['Street Address'].str.lower()
df1['Source Zipcode'] = df1['Source Zipcode'].astype('object')
df1.head()
# Out:
#        Location Id  Business Account Number Ownership Name           DBA Name  \
# 5   1157686-08-171                  1074591       Alice Ho        Little Kite
# 17  1090504-08-161                  1043060     Lai Junwen  Chase Luck Bakery
# 22  1140840-03-171                  1067644  Bogurtlen Inc          Bogurtlen
# 26  1142723-04-171                  1039498  Communion Inc    Communion Juice
# 47  1125254-10-161                  1059484    Tian Qiyuan              One +
#
#    Street Address           City State Source Zipcode Business Start Date  \
# 5           th st  San Francisco    CA          94110           8/10/2017
# 17            NaN  San Francisco    CA          94112           8/18/2016
# 22                   Foster City    CA          94404           3/24/2017
# 26            NaN  San Francisco    CA          94124           7/13/2016
# 47            NaN  San Francisco    CA          94112          10/12/2016
#
#    Business End Date  ... NAICS Code Description Parking Tax  \
# 5         12/31/2018  ...          Food Services       False
# 17        12/25/2016  ...          Food Services       False
# 22         7/20/2017  ...          Food Services       False
# 26          1/1/2017  ...          Food Services       False
# 47         5/14/2019  ...          Food Services       False
#
#    Transient Occupancy Tax LIC Code LIC Code Description Supervisor District  \
# 5                    False      H26                  NaN                 NaN
# 17                   False      NaN                  NaN                 NaN
# 22                   False      NaN                  NaN                 NaN
# 26                   False      NaN                  NaN                 NaN
# 47                   False      H98                  NaN                 NaN
#
#    Neighborhoods - Analysis Boundaries Business Corridor  Business Location  \
# 5                                  NaN               NaN                NaN
# 17                                 NaN               NaN                NaN
# 22                                 NaN               NaN                NaN
# 26                                 NaN               NaN                NaN
# 47                                 NaN               NaN                NaN
#
#     Address Number
# 5               20
# 17             NaN
# 22             105
# 26             NaN
# 47             NaN
#
# [5 rows x 27 columns]

# %%
a = pd.read_csv('./listings.csv',index_col='id')
a.head()
lst = ['listing_url','scrape_id','last_scraped','summary',\
       'space','description','experiences_offered','neighborhood_overview','interaction','access','house_rules',\
       'notes','thumbnail_url','medium_url','picture_url','host_url',\
      'host_about','host_response_rate','host_acceptance_rate','host_thumbnail_url','host_picture_url',\
       'host_listings_count','host_has_profile_pic','host_verifications','host_neighbourhood',\
       'neighbourhood_cleansed','neighbourhood_group_cleansed','market','smart_location','country_code',\
      'country','is_location_exact','square_feet','weekly_price','monthly_price','minimum_minimum_nights',\
      'minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights',\
      'minimum_nights_avg_ntm','maximum_nights_avg_ntm','calendar_updated','has_availability','calendar_last_scraped',\
      'availability_30','availability_60','availability_90','availability_365','number_of_reviews_ltm',\
       'requires_license','license','jurisdiction_names','is_business_travel_ready','require_guest_profile_picture',\
      'require_guest_phone_verification','calculated_host_listings_count','calculated_host_listings_count_entire_homes',\
      'calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms','xl_picture_url',\
      ]
a.drop(columns=lst,inplace=True)

# %%
a.shape
# Out:
# (8111, 45)

# %%
a.columns
# Out:
# Index(['name', 'transit', 'host_id', 'host_name', 'host_since',
#        'host_location', 'host_response_time', 'host_is_superhost',
#        'host_total_listings_count', 'host_identity_verified', 'street',
#        'neighbourhood', 'city', 'state', 'zipcode', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'amenities', 'price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'number_of_reviews', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'instant_bookable', 'cancellation_policy',
#        'reviews_per_month'],
#       dtype='object')

# %%
df2.isna().sum().sum()
df2 = df2[df2.city=='San Francisco']
df2.head()
# Out:
#                             listing_url     scrape_id last_scraped  \
# id
# 958    https://www.airbnb.com/rooms/958  2.019100e+13     10/14/19
# 3850  https://www.airbnb.com/rooms/3850  2.019100e+13     10/14/19
# 5858  https://www.airbnb.com/rooms/5858  2.019100e+13     10/14/19
# 7918  https://www.airbnb.com/rooms/7918  2.019100e+13     10/14/19
# 8142  https://www.airbnb.com/rooms/8142  2.019100e+13     10/14/19
#
#                                                    name  \
# id
# 958                 Bright, Modern Garden Unit - 1BR/1B
# 3850                              Charming room for two
# 5858                                 Creative Sanctuary
# 7918         A Friendly Room - UCSF/USF - San Francisco
# 8142  Friendly Room Apt. Style -UCSF/USF - San Franc...
#
#                                                 summary  \
# id
# 958   New update: the house next door is under const...
# 3850  Your own private room plus access to a shared ...
# 5858                                                NaN
# 7918  Nice and good public transportation.  7 minute...
# 8142  Nice and good public transportation.  7 minute...
#
#                                                   space  \
# id
# 958   Newly remodeled, modern, and bright garden uni...
# 3850  This room can fit two people. Nobody else will...
# 5858  We live in a large Victorian house on a quiet ...
# 7918  Settle down, S.F. resident, student, hospital,...
# 8142  Settle down, S.F. resident, student, hospital,...
#
#                                             description experiences_offered  \
# id
# 958   New update: the house next door is under const...                none
# 3850  Your own private room plus access to a shared ...                none
# 5858  We live in a large Victorian house on a quiet ...                none
# 7918  Nice and good public transportation.  7 minute...                none
# 8142  Nice and good public transportation.  7 minute...                none
#
#                                   neighborhood_overview  \
# id
# 958   *Quiet cul de sac in friendly neighborhood *St...
# 3850  This is a quiet, safe neighborhood on a substa...
# 5858  I love how our neighborhood feels quiet but is...
# 7918  Shopping old town, restaurants, McDonald, Whol...
# 8142                                                NaN
#
#                                                   notes  \
# id
# 958   Due to the fact that we have children and a do...
# 3850  House Rule footnotes: 1.\tI don’t allow check ...
# 5858  All the furniture in the house was handmade so...
# 7918  Wi-Fi signal in common areas.   Large eat in k...
# 8142  Wi-Fi signal in common areas.   Large eat in k...
#
#                                                 transit  \
# id
# 958   *Public Transportation is 1/2 block away.  *Ce...
# 3850  Public transit service to my house is outstand...
# 5858  The train is two blocks away and you can stop ...
# 7918         N Juda Muni and bus stop.  Street parking.
# 8142  N Juda Muni, Bus and UCSF Shuttle. small shopp...
#
#                                                  access  \
# id
# 958   *Full access to patio and backyard (shared wit...
# 3850  During the hours of 7:00 to 22:00, your access...
# 5858  Our deck, garden, gourmet kitchen and extensiv...
# 7918                                                NaN
# 8142                                                NaN
#
#                                             interaction  \
# id
# 958   A family of 4 lives upstairs with their dog. N...
# 3850  I live at the house in my own bedroom, and I w...
# 5858                                                NaN
# 7918                                                NaN
# 8142                                                NaN
#
#                                             house_rules  thumbnail_url  \
# id
# 958   * No Pets - even visiting guests for a short t...            NaN
# 3850  Airbnb has no default house rules that hosts c...            NaN
# 5858  Please respect the house, the art work, the fu...            NaN
# 7918  No party, No smoking, not for any kinds of smo...            NaN
# 8142       no pet no smoke no party inside the building            NaN
#
#       medium_url                                        picture_url  \
# id
# 958          NaN  https://a0.muscache.com/im/pictures/b7c2a199-4...
# 3850         NaN  https://a0.muscache.com/im/pictures/b6e97d2a-1...
# 5858         NaN  https://a0.muscache.com/im/pictures/17714/3a7a...
# 7918         NaN  https://a0.muscache.com/im/pictures/26356/8030...
# 8142         NaN  https://a0.muscache.com/im/pictures/27832/3b1f...
#
#       xl_picture_url  host_id                                 host_url  \
# id
# 958              NaN     1169   https://www.airbnb.com/users/show/1169
# 3850             NaN     4921   https://www.airbnb.com/users/show/4921
# 5858             NaN     8904   https://www.airbnb.com/users/show/8904
# 7918             NaN    21994  https://www.airbnb.com/users/show/21994
# 8142             NaN    21994  https://www.airbnb.com/users/show/21994
#
#              host_name host_since                             host_location  \
# id
# 958              Holly    7/31/08  San Francisco, California, United States
# 3850             Kevin    12/8/08  San Francisco, California, United States
# 5858  Philip And Tania     3/2/09  San Francisco, California, United States
# 7918             Aaron    6/17/09  San Francisco, California, United States
# 8142             Aaron    6/17/09  San Francisco, California, United States
#
#                                              host_about host_response_time  \
# id
# 958   We are a family with 2 boys born in 2009 and 2...       within a day
# 3850  I am a retired software developer now raising ...     within an hour
# 5858  Philip: English transplant to the Bay Area and...       within a day
# 7918  7 minutes walk to UCSF hospital & school campu...     within an hour
# 8142  7 minutes walk to UCSF hospital & school campu...     within an hour
#
#      host_response_rate  host_acceptance_rate host_is_superhost  \
# id
# 958                100%                   NaN                 t
# 3850               100%                   NaN                 t
# 5858                80%                   NaN                 f
# 7918                86%                   NaN                 t
# 8142                86%                   NaN                 t
#
#                                      host_thumbnail_url  \
# id
# 958   https://a0.muscache.com/im/pictures/efdad96a-3...
# 3850  https://a0.muscache.com/im/pictures/97d29791-d...
# 5858  https://a0.muscache.com/im/users/8904/profile_...
# 7918  https://a0.muscache.com/im/users/21994/profile...
# 8142  https://a0.muscache.com/im/users/21994/profile...
#
#                                        host_picture_url host_neighbourhood  \
# id
# 958   https://a0.muscache.com/im/pictures/efdad96a-3...    Duboce Triangle
# 3850  https://a0.muscache.com/im/pictures/97d29791-d...       Inner Sunset
# 5858  https://a0.muscache.com/im/users/8904/profile_...     Bernal Heights
# 7918  https://a0.muscache.com/im/users/21994/profile...        Cole Valley
# 8142  https://a0.muscache.com/im/users/21994/profile...        Cole Valley
#
#       host_listings_count  host_total_listings_count  \
# id
# 958                   1.0                        1.0
# 3850                  2.0                        2.0
# 5858                  2.0                        2.0
# 7918                 10.0                       10.0
# 8142                 10.0                       10.0
#
#                                      host_verifications host_has_profile_pic  \
# id
# 958    ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 3850  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 5858  ['email', 'phone', 'reviews', 'kba', 'work_ema...                    t
# 7918  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 8142  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
#
#      host_identity_verified                            street  \
# id
# 958                       t  San Francisco, CA, United States
# 3850                      t  San Francisco, CA, United States
# 5858                      t  San Francisco, CA, United States
# 7918                      t  San Francisco, CA, United States
# 8142                      t  San Francisco, CA, United States
#
#         neighbourhood neighbourhood_cleansed  neighbourhood_group_cleansed  \
# id
# 958   Duboce Triangle       Western Addition                           NaN
# 3850     Inner Sunset           Inner Sunset                           NaN
# 5858   Bernal Heights         Bernal Heights                           NaN
# 7918      Cole Valley         Haight Ashbury                           NaN
# 8142      Cole Valley         Haight Ashbury                           NaN
#
#                city state zipcode         market     smart_location  \
# id
# 958   San Francisco    CA   94117  San Francisco  San Francisco, CA
# 3850  San Francisco    CA   94131  San Francisco  San Francisco, CA
# 5858  San Francisco    CA   94110  San Francisco  San Francisco, CA
# 7918  San Francisco    CA   94117  San Francisco  San Francisco, CA
# 8142  San Francisco    CA   94117  San Francisco  San Francisco, CA
#
#      country_code        country  latitude  longitude is_location_exact  \
# id
# 958            US  United States  37.76931 -122.43386                 t
# 3850           US  United States  37.75402 -122.45805                 t
# 5858           US  United States  37.74511 -122.42102                 t
# 7918           US  United States  37.76669 -122.45250                 t
# 8142           US  United States  37.76487 -122.45183                 t
#
#      property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# id
# 958      Apartment  Entire home/apt             3        1.0       1.0   2.0
# 3850         House     Private room             2        1.0       1.0   1.0
# 5858     Apartment  Entire home/apt             5        1.0       2.0   3.0
# 7918     Apartment     Private room             2        4.0       1.0   1.0
# 8142     Apartment     Private room             2        4.0       1.0   1.0
#
#       bed_type                                          amenities  \
# id
# 958   Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,"Pets liv...
# 3850  Real Bed  {Internet,Wifi,Kitchen,Breakfast,"Free street ...
# 5858  Real Bed  {Internet,Wifi,Kitchen,Heating,"Family/kid fri...
# 7918  Real Bed  {TV,Internet,Wifi,Kitchen,"Free street parking...
# 8142  Real Bed  {TV,Internet,Wifi,Kitchen,"Free street parking...
#
#       square_feet     price weekly_price monthly_price security_deposit  \
# id
# 958           NaN  $170.00    $1,120.00     $4,200.00          $100.00
# 3850          NaN   $99.00           NaN           NaN           $0.00
# 5858          NaN  $235.00    $1,600.00     $5,500.00               NaN
# 7918          NaN   $65.00      $485.00     $1,685.00          $200.00
# 8142          NaN   $65.00      $490.00     $1,685.00          $200.00
#
#      cleaning_fee  guests_included extra_people  minimum_nights  \
# id
# 958      $100.00                 2      $25.00                1
# 3850      $10.00                 2      $20.00                1
# 5858     $100.00                 2       $0.00               30
# 7918      $50.00                 1      $12.00               32
# 8142      $50.00                 1      $12.00               32
#
#       maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# id
# 958               30                       1                       1
# 3850               5                       1                       1
# 5858              60                      30                      30
# 7918              60                      32                      32
# 8142              90                      32                      32
#
#       minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# id
# 958                       30                      30                     1.0
# 3850                       5                       5                     1.0
# 5858                      60                      60                    30.0
# 7918                      60                      60                    32.0
# 8142                      90                      90                    32.0
#
#       maximum_nights_avg_ntm calendar_updated has_availability  \
# id
# 958                     30.0     2 months ago                t
# 3850                     5.0       3 days ago                t
# 5858                    60.0      3 weeks ago                t
# 7918                    60.0     3 months ago                t
# 8142                    90.0     3 months ago                t
#
#       availability_30  availability_60  availability_90  availability_365  \
# id
# 958                 3                8               16                85
# 3850                5               32               62                62
# 5858                0                0                0                 0
# 7918               30               60               90               365
# 8142               30               60               90               365
#
#      calendar_last_scraped  number_of_reviews  number_of_reviews_ltm  \
# id
# 958               10/14/19                217                     52
# 3850              10/14/19                160                     36
# 5858              10/14/19                111                      0
# 7918              10/14/19                 18                      1
# 8142              10/14/19                  8                      0
#
#      first_review last_review  review_scores_rating  review_scores_accuracy  \
# id
# 958       7/23/09     9/21/19                  97.0                    10.0
# 3850      7/16/09     9/30/19                  94.0                    10.0
# 5858       5/3/09      8/6/17                  98.0                    10.0
# 7918      8/31/09     9/10/19                  86.0                     8.0
# 8142       9/8/14     9/12/18                  93.0                     9.0
#
#       review_scores_cleanliness  review_scores_checkin  \
# id
# 958                        10.0                   10.0
# 3850                       10.0                   10.0
# 5858                       10.0                   10.0
# 7918                        8.0                    9.0
# 8142                        9.0                   10.0
#
#       review_scores_communication  review_scores_location  \
# id
# 958                          10.0                    10.0
# 3850                         10.0                    10.0
# 5858                         10.0                    10.0
# 7918                          9.0                     9.0
# 8142                         10.0                     9.0
#
#       review_scores_value requires_license      license jurisdiction_names  \
# id
# 958                   9.0                t  STR-0001256  {"SAN FRANCISCO"}
# 3850                 10.0                t  STR-0000346  {"SAN FRANCISCO"}
# 5858                  9.0                t          NaN  {"SAN FRANCISCO"}
# 7918                  8.0                t          NaN  {"SAN FRANCISCO"}
# 8142                  9.0                t          NaN  {"SAN FRANCISCO"}
#
#      instant_bookable is_business_travel_ready          cancellation_policy  \
# id
# 958                 f                        f                     moderate
# 3850                f                        f  strict_14_with_grace_period
# 5858                f                        f  strict_14_with_grace_period
# 7918                f                        f  strict_14_with_grace_period
# 8142                f                        f  strict_14_with_grace_period
#
#      require_guest_profile_picture require_guest_phone_verification  \
# id
# 958                              f                                f
# 3850                             f                                f
# 5858                             f                                f
# 7918                             f                                f
# 8142                             f                                f
#
#       calculated_host_listings_count  \
# id
# 958                                1
# 3850                               3
# 5858                               1
# 7918                               9
# 8142                               9
#
#       calculated_host_listings_count_entire_homes  \
# id
# 958                                             1
# 3850                                            0
# 5858                                            1
# 7918                                            0
# 8142                                            0
#
#       calculated_host_listings_count_private_rooms  \
# id
# 958                                              0
# 3850                                             3
# 5858                                             0
# 7918                                             9
# 8142                                             9
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# id
# 958                                             0               1.74
# 3850                                            0               1.28
# 5858                                            0               0.87
# 7918                                            0               0.15
# 8142                                            0               0.13

# %%
df = df2.merge(df1,left_on='zipcode',right_on='Source Zipcode')
df.info()

df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-781a5aadfd86> in <module>
# ----> 1 df = df2.merge(df1,left_on='zipcode',right_on='Source Zipcode')
#       2 df.info()
#       3
#       4 df.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7332             copy=copy,
#    7333             indicator=indicator,
# -> 7334             validate=validate,
#    7335         )
#    7336
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     628         # validate the merge keys dtypes. We may need to coerce
#     629         # to avoid incompat dtypes
# --> 630         self._maybe_coerce_merge_keys()
#     631
#     632         # If argument passed to validate,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#    1136                     inferred_right in string_types and inferred_left not in string_types
#    1137                 ):
# -> 1138                     raise ValueError(msg)
#    1139
#    1140             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and float64 columns. If you wish to proceed you should use pd.concat

# %%
df[(df['Ownership Name']=='Malik Alia')]
# Out:
#                                  listing_url     scrape_id last_scraped  \
# 0       https://www.airbnb.com/rooms/1565576  2.019100e+13     10/14/19
# 84      https://www.airbnb.com/rooms/2056660  2.019100e+13     10/14/19
# 168     https://www.airbnb.com/rooms/2290365  2.019100e+13     10/14/19
# 252     https://www.airbnb.com/rooms/3093070  2.019100e+13     10/14/19
# 336     https://www.airbnb.com/rooms/4226601  2.019100e+13     10/14/19
# ...                                      ...           ...          ...
# 19236  https://www.airbnb.com/rooms/35649755  2.019100e+13     10/14/19
# 19320  https://www.airbnb.com/rooms/35876104  2.019100e+13     10/14/19
# 19404  https://www.airbnb.com/rooms/35988720  2.019100e+13     10/14/19
# 19488  https://www.airbnb.com/rooms/36312772  2.019100e+13     10/14/19
# 19572  https://www.airbnb.com/rooms/36312974  2.019100e+13     10/14/19
#
#                                                     name  \
# 0        Modern Condo with Victorian charm in Noe Valley
# 84             Cute Studio Apart w/Lots of Natural Light
# 168    Best Location, renovated, clean and great revi...
# 252    Two Rooms in SF House with Magical Garden & Vi...
# 336      Sunny Sanctuary in the Trees - Mission District
# ...                                                  ...
# 19236    Modern Studio in SoMa, near BART + Top Tech HQs
# 19320      Bright 2BR in San Francisco, Near Ocean Beach
# 19404    Bright 2BR Condo in Nob Hill, Balcony + Parking
# 19488  Charming Studio in Nob Hill, .5 mi to Union Sq...
# 19572  Lovely Studio Apartment in Nob Hill, Pets Welcome
#
#                                                  summary  \
# 0      Comfy Condo!  Located in a quiet neighborhood,...
# 84     PREFER 2 MONTH RESERVATION: This is a cute pri...
# 168    Reviews: "Tal's place was in a great location"...
# 252    Discover the best of San Francisco atop beauti...
# 336    Stay in a bright and airy apartment nestled in...
# ...                                                  ...
# 19236  At Zeus, we focus exclusively on 30 day+ stays...
# 19320  At Zeus, we focus exclusively on 30 day+ stays...
# 19404  At Zeus, we focus exclusively on 30 day+ stays...
# 19488  At Zeus, we focus exclusively on 30 day+ stays...
# 19572  At Zeus, we focus exclusively on 30 day+ stays...
#
#                                                    space  \
# 0      Parking is possible on the street, but you wou...
# 84     Tastefully decorated studio apartment in the h...
# 168    The condo was *just* remodeled in November 201...
# 252    This is the first floor (street level) of a un...
# 336    The apartment is a sunny and spacious 1 bedroo...
# ...                                                  ...
# 19236  At Zeus, we focus exclusively on 30 day+ stays...
# 19320  At Zeus, we focus exclusively on 30 day+ stays...
# 19404  At Zeus, we focus exclusively on 30 day+ stays...
# 19488  At Zeus, we focus exclusively on 30 day+ stays...
# 19572  At Zeus, we focus exclusively on 30 day+ stays...
#
#                                              description experiences_offered  \
# 0      Comfy Condo!  Located in a quiet neighborhood,...                none
# 84     PREFER 2 MONTH RESERVATION: This is a cute pri...                none
# 168    Reviews: "Tal's place was in a great location"...                none
# 252    Discover the best of San Francisco atop beauti...                none
# 336    Stay in a bright and airy apartment nestled in...                none
# ...                                                  ...                 ...
# 19236  At Zeus, we focus exclusively on 30 day+ stays...                none
# 19320  At Zeus, we focus exclusively on 30 day+ stays...                none
# 19404  At Zeus, we focus exclusively on 30 day+ stays...                none
# 19488  At Zeus, we focus exclusively on 30 day+ stays...                none
# 19572  At Zeus, we focus exclusively on 30 day+ stays...                none
#
#                                    neighborhood_overview  \
# 0      Small neighborhood with anything you might nee...
# 84     Close to everything - City Hall, Civic Center ...
# 168    The Mission District's multifarious corridors ...
# 252    Bernal Heights was voted America's hottest nei...
# 336    The apartment is located in the center of the ...
# ...                                                  ...
# 19236                                                NaN
# 19320                                                NaN
# 19404                                                NaN
# 19488                                                NaN
# 19572                                                NaN
#
#                                                    notes  ...  \
# 0      Noise absorption is not optimal at location so...  ...
# 84     Please contact me so we can discuss how to int...  ...
# 168    I love hosting and I look forward to welcoming...  ...
# 252    We are LGBT friendly. We are 420 friendly too!...  ...
# 336                                                  NaN  ...
# ...                                                  ...  ...
# 19236                                                NaN  ...
# 19320   • Can at times hear noise from neighboring units  ...
# 19404                                                NaN  ...
# 19488                                                NaN  ...
# 19572  • This unit is street facing and can hear traf...  ...
#
#       NAICS Code Description Parking Tax Transient Occupancy Tax LIC Code  \
# 0              Food Services       False                   False      NaN
# 84             Food Services       False                   False      NaN
# 168            Food Services       False                   False      NaN
# 252            Food Services       False                   False      NaN
# 336            Food Services       False                   False      NaN
# ...                      ...         ...                     ...      ...
# 19236          Food Services       False                   False      NaN
# 19320          Food Services       False                   False      NaN
# 19404          Food Services       False                   False      NaN
# 19488          Food Services       False                   False      NaN
# 19572          Food Services       False                   False      NaN
#
#        LIC Code Description  Supervisor District  \
# 0                       NaN                  NaN
# 84                      NaN                  NaN
# 168                     NaN                  NaN
# 252                     NaN                  NaN
# 336                     NaN                  NaN
# ...                     ...                  ...
# 19236                   NaN                  NaN
# 19320                   NaN                  NaN
# 19404                   NaN                  NaN
# 19488                   NaN                  NaN
# 19572                   NaN                  NaN
#
#       Neighborhoods - Analysis Boundaries  Business Corridor  \
# 0                                     NaN                NaN
# 84                                    NaN                NaN
# 168                                   NaN                NaN
# 252                                   NaN                NaN
# 336                                   NaN                NaN
# ...                                   ...                ...
# 19236                                 NaN                NaN
# 19320                                 NaN                NaN
# 19404                                 NaN                NaN
# 19488                                 NaN                NaN
# 19572                                 NaN                NaN
#
#                 Business Location Address Number
# 0      POINT (-122.37688 37.7343)            NaN
# 84     POINT (-122.37688 37.7343)            NaN
# 168    POINT (-122.37688 37.7343)            NaN
# 252    POINT (-122.37688 37.7343)            NaN
# 336    POINT (-122.37688 37.7343)            NaN
# ...                           ...            ...
# 19236  POINT (-122.37688 37.7343)            NaN
# 19320  POINT (-122.37688 37.7343)            NaN
# 19404  POINT (-122.37688 37.7343)            NaN
# 19488  POINT (-122.37688 37.7343)            NaN
# 19572  POINT (-122.37688 37.7343)            NaN
#
# [234 rows x 132 columns]

# %%
a = df1[df1.City=='San Francisco'].groupby('Ownership Name')['Street Address'].value_counts()
a
#df1['Ownership Name'] & df1['City']=='San Francisco']
# Out:
# Ownership Name           Street Address
# 10 6th St. Llc           th st             1
# 1058 Hoagie Llc          th st 102         1
# 11th Street Pizza Inc    th st             1
# 1455 Market Street       b                 1
# 16th St Taco Inc         th st             1
#                                           ..
# Zoila Benita Apesteguia                    1
# Zou Yu                   rd st             1
# Zughaiyir Muhammad A                       1
#                          rd st             1
# Zume, Inc.               nd                1
# Name: Street Address, Length: 2512, dtype: int64
