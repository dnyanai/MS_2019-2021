# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns',150)

# %%
a = pd.read_csv('./listings.csv')
a.head(1)
# Out:
#     id                       listing_url       scrape_id last_scraped  \
# 0  109  https://www.airbnb.com/rooms/109  20190708161040   2019-07-09
#
#                                                 name  \
# 0  Amazing bright elegant condo park front *UPGRA...
#
#                                              summary  \
# 0  *** Unit upgraded with new bamboo flooring, br...
#
#                                                space  \
# 0  *** Unit upgraded with new bamboo flooring, br...
#
#                                          description experiences_offered  \
# 0  *** Unit upgraded with new bamboo flooring, br...                none
#
#   neighborhood_overview notes transit access interaction  \
# 0                   NaN   NaN     NaN    NaN         NaN
#
#                                          house_rules  thumbnail_url  \
# 0  Camelot NEW RESIDENTS’ GENERAL INFORMATION   F...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/4321499/1d...
#
#    xl_picture_url  host_id                               host_url host_name  \
# 0             NaN      521  https://www.airbnb.com/users/show/521     Paolo
#
#    host_since                             host_location  \
# 0  2008-06-27  San Francisco, California, United States
#
#                                           host_about host_response_time  \
# 0  Search for me on the Internet with the keyword...                NaN
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                NaN                   NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/521/profile_p...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/521/profile_p...        Culver City
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
#
#                                  host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
#
#   host_identity_verified                          street neighbourhood  \
# 0                      t  Culver City, CA, United States   Culver City
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed         city state  \
# 0            Culver City                           NaN  Culver City    CA
#
#   zipcode       market   smart_location country_code        country  latitude  \
# 0   90230  Los Angeles  Culver City, CA           US  United States  33.98209
#
#    longitude is_location_exact property_type        room_type  accommodates  \
# 0 -118.38494                 t   Condominium  Entire home/apt             6
#
#    bathrooms  bedrooms  beds  bed_type  \
# 0        2.0       2.0   3.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $122.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0      $904.00     $2,851.00          $500.00      $240.00                3
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $25.00              30             730                      30
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                      30                     730                     730
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                    30.0                   730.0     5 months ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                0                0                0
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0                98            2019-07-09                  2
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      0   2011-08-15  2016-05-15                  80.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                    6.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          8.0                    10.0                  8.0
#
#   requires_license license     jurisdiction_names instant_bookable  \
# 0                f     NaN  {"Culver City"," CA"}                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             t                                f
#
#    calculated_host_listings_count  \
# 0                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.02

# %%
lst = ['listing_url','scrape_id','last_scraped','summary',\
       'space','description','experiences_offered','neighborhood_overview','interaction','access','house_rules',\
       'notes','thumbnail_url','medium_url','picture_url','host_url',\
      'host_about','host_response_rate','host_acceptance_rate','host_thumbnail_url','host_picture_url',\
       'host_listings_count','host_has_profile_pic','host_verifications','host_neighbourhood',\
       'neighbourhood_cleansed','neighbourhood_group_cleansed','market','smart_location','country_code',\
      'country','is_location_exact','square_feet','weekly_price','monthly_price','minimum_minimum_nights',\
      'minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights',\
      'minimum_nights_avg_ntm','maximum_nights_avg_ntm','calendar_updated','has_availability','calendar_last_scraped',\
      'availability_30','availability_60','availability_90','availability_365','number_of_reviews_ltm',\
       'requires_license','license','jurisdiction_names','is_business_travel_ready','require_guest_profile_picture',\
      'require_guest_phone_verification','calculated_host_listings_count','calculated_host_listings_count_entire_homes',\
      'calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms','xl_picture_url',\
      ]
a.drop(columns=lst,inplace=True)

# %%
a.shape
# Out:
# (44620, 46)

# %%
df = a.copy()

# %%
df['colid'] = df.index

# %%
df.head(2)
df.drop('id',axis=1,inplace=True)

# %%
#df1 = df[['id','colid']].copy()
#.reset_index(drop=True,inplace=True)
df.rename(columns={'colid':'id'},inplace=True)

# %%
df.id +=1

# %%
df.set_index('id')
df.head(1)
# Out:
#                                                 name transit  host_id  \
# 0  Amazing bright elegant condo park front *UPGRA...     NaN      521
#
#   host_name  host_since                             host_location  \
# 0     Paolo  2008-06-27  San Francisco, California, United States
#
#   host_response_time host_is_superhost  host_total_listings_count  \
# 0                NaN                 f                        1.0
#
#   host_identity_verified                          street neighbourhood  \
# 0                      t  Culver City, CA, United States   Culver City
#
#           city state zipcode  latitude  longitude property_type  \
# 0  Culver City    CA   90230  33.98209 -118.38494   Condominium
#
#          room_type  accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0  Entire home/apt             6        2.0       2.0   3.0  Real Bed
#
#                                            amenities    price  \
# 0  {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $122.00
#
#   security_deposit cleaning_fee  guests_included extra_people  minimum_nights  \
# 0          $500.00      $240.00                3       $25.00              30
#
#    maximum_nights  number_of_reviews first_review last_review  \
# 0             730                  2   2011-08-15  2016-05-15
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  80.0                    10.0                       10.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                    6.0                          8.0                    10.0
#
#    review_scores_value instant_bookable          cancellation_policy  \
# 0                  8.0                f  strict_14_with_grace_period
#
#    reviews_per_month  id
# 0               0.02   1

# %%
#top10names = list(df.accommodates.value_counts().nlargest(10).index)

#a = df.loc[df.accommodates.isin(top10names),'accommodates']
#df.plot(x='accommodates',y=['bedrooms'],kind='bar')

# %% [markdown]
# ## Cleaning the city column & state column

# %%
#df.rename(index={'Afghanistan':'Afghanistan_renamed'})
df.state.loc[df.state=='California'] = 'CA'
df.state.unique()
df.state = df['state'].str.upper()

# %%
df.state.value_counts()
# Out:
# CA    44611
# 加州        2
# NY        2
# FL        1
# IL        1
# 加洲        1
# Name: state, dtype: int64

# %%
#df[~(df.state=='CA')].drop
#df1.drop(df1[(df1['Year'].values==1970)].index,axis=0,inplace=True)
#a = df.state[~(df.state=='CA')]
df.drop(df[~(df.state.values=='CA')].index,axis=0,inplace=True)

# %%
#df.groupby('host_location')['city'].unique()
df.city = df.city.str.lower()

df.city.loc[df.city=='n hollywood'] = 'north hollywood'
df.city.loc[df.city=='n hollywood'] = 'north hollywood'
df.city.loc[df.city=='granada hills, (los angeles)'] = 'granada hills'
df.city.unique()
#df.loc[df.city=='venice'].groupby('neighbourhood')['street'].value_counts()
df.city.dropna(inplace=True)
df.city.str.contains('venice').value_counts()
#df.city.iloc[a[0]]
# Out:
# False    44185
# True       406
# Name: city, dtype: int64

# %%
df['city'] = df['city'].str.replace(r'[^\x00-\x7F]+', '')
df.city.dropna(inplace=True)
df.city.value_counts()
# Out:
# los angeles              27933
# long beach                1612
# santa monica              1059
# west hollywood             973
# beverly hills              767
#                          ...
# montebello                   1
# playa                        1
# universal city               1
# quartz hill                  1
# pasadena, los angeles        1
# Name: city, Length: 334, dtype: int64
