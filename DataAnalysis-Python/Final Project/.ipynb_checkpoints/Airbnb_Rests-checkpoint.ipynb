# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('./Registered_Business_Locations_-_San_Francisco.csv')

# %%
df1 = df1[df1['NAICS Code Description']=='Food Services']
df1['Street Address'].count()
# Out:
# 13123

# %%
df1.head()
df = df1['Street Address'].str.extract('(?P<Address_Number>\d+)(?P<Street_Address>.*)', expand=True)
#print (df)
df1['Address Number'] = df.Address_Number
df1['Street Address'] = df.Street_Address
df1['Street Address'] = df1['Street Address'].str.lower()
df1
# Out:
#            Location Id  Business Account Number         Ownership Name  \
# 5       1157686-08-171                  1074591               Alice Ho
# 17      1090504-08-161                  1043060             Lai Junwen
# 22      1140840-03-171                  1067644          Bogurtlen Inc
# 26      1142723-04-171                  1039498          Communion Inc
# 47      1125254-10-161                  1059484            Tian Qiyuan
# ...                ...                      ...                    ...
# 254097  1245953-02-201                   481127            Diab Eman M
# 254101  1246065-02-201                  1111770  World Wrapps Ii, Inc.
# 254102  1246084-02-201                  1111770  World Wrapps Ii, Inc.
# 254114  1246327-02-201                  1086545   Richmond Restaurants
# 254128  1246877-02-201                  1112115       Gourmet Medicine
#
#                  DBA Name                        Street Address  \
# 5             Little Kite                               20th st
# 17      Chase Luck Bakery                             ocean ave
# 22              Bogurtlen                         bounty dr 105
# 26        Communion Juice                        horne ave bldg
# 47                  One +                             prague st
# ...                   ...                                   ...
# 254097         Emo's Cafe                               turk st
# 254101       World Wrapps   corte madera town center ctr ste460
# 254102       World Wrapps                            chesnut st
# 254114              Aziza                              geary st
# 254128   Gourmet Medicine                    kiska rd.  apt 207
#
#                  City State  Source Zipcode Business Start Date  \
# 5       San Francisco    CA         94110.0           8/10/2017
# 17      San Francisco    CA         94112.0           8/18/2016
# 22        Foster City    CA         94404.0           3/24/2017
# 26      San Francisco    CA         94124.0           7/13/2016
# 47      San Francisco    CA         94112.0          10/12/2016
# ...               ...   ...             ...                 ...
# 254097  San Francisco    CA         94102.0            7/4/2013
# 254101   Corte Madera    CA         94925.0           2/13/2020
# 254102  San Francisco    CA         94123.0           2/13/2020
# 254114  San Francisco    CA         94105.0            2/1/2018
# 254128  San Francisco    CA         94124.0           2/22/2020
#
#        Business End Date  ... NAICS Code Description Parking Tax  \
# 5             12/31/2018  ...          Food Services       False
# 17            12/25/2016  ...          Food Services       False
# 22             7/20/2017  ...          Food Services       False
# 26              1/1/2017  ...          Food Services       False
# 47             5/14/2019  ...          Food Services       False
# ...                  ...  ...                    ...         ...
# 254097               NaN  ...          Food Services       False
# 254101               NaN  ...          Food Services       False
# 254102               NaN  ...          Food Services       False
# 254114               NaN  ...          Food Services       False
# 254128               NaN  ...          Food Services       False
#
#        Transient Occupancy Tax LIC Code             LIC Code Description  \
# 5                        False      H26                              NaN
# 17                       False      NaN                              NaN
# 22                       False      NaN                              NaN
# 26                       False      NaN                              NaN
# 47                       False      H98                              NaN
# ...                        ...      ...                              ...
# 254097                   False      H24  RESTAURANT LESS THAN 1,000 SQFT
# 254101                   False      NaN                              NaN
# 254102                   False      NaN                              NaN
# 254114                   False  D04 D19                         Multiple
# 254128                   False      NaN                              NaN
#
#        Supervisor District Neighborhoods - Analysis Boundaries  \
# 5                      NaN                                 NaN
# 17                     NaN                                 NaN
# 22                     NaN                                 NaN
# 26                     NaN                                 NaN
# 47                     NaN                                 NaN
# ...                    ...                                 ...
# 254097                 6.0                          Tenderloin
# 254101                 NaN                                 NaN
# 254102                 NaN                                 NaN
# 254114                 NaN                                 NaN
# 254128                10.0               Bayview Hunters Point
#
#        Business Corridor  Business Location  Address Number
# 5                    NaN                NaN            3515
# 17                   NaN                NaN            1325
# 22                   NaN                NaN             877
# 26                   NaN                NaN             103
# 47                   NaN                NaN             166
# ...                  ...                ...             ...
# 254097               NaN                NaN             201
# 254101               NaN                NaN             145
# 254102               NaN                NaN            2105
# 254114               NaN                NaN            5800
# 254128               NaN                NaN             145
#
# [13123 rows x 27 columns]

# %%
df1 = pd.read_csv('./listingd.csv')

# %%
# Out:
#           OSP_ID           FACILITY_NAME          STREET_ADDRESS  \
# OBJECTID
# 25           893           Pier 52 Lot B   terry a francois blvd
# 37           907  Mission and Norton Lot           norton street
# 27           925      7th & Harrison Lot              7th street
# 45           903     8th and Clement Lot             08th avenue
# 23           950     Union Square Garage             post street
#
#                                   LOCATION           PHONE  PM_DISTRICT_ID  \
# OBJECTID
# 25                Terry Francois @ Pier 52             NaN             2.0
# 37        Norton between Mission & Alemany             NaN            35.0
# 27        7th St between Harrison & Bryant  (415) 558-9052             NaN
# 45         8th Ave between Clement & Geary             NaN             9.0
# 23         Geary between Stockton & Powell  (415) 397-0631             1.0
#
#          AREA_TYPE  BLOCKFACE_ID  STREET_SEG_CTRLN_ID FACILITY_TYPE  ...  \
# OBJECTID                                                             ...
# 25           Pilot        869051             12532004             L  ...
# 37               -        584002              9714000             L  ...
# 27           Pilot        207042               374000             G  ...
# 45         Control        108032               389000             L  ...
# 23           Pilot        614031             10628000             G  ...
#
#          CARD_REPLACE_FEE LATE_FEE REOPEN_FEE NO_KEY_VALET_FEE CAPACITY  \
# OBJECTID
# 25                      0        0          0                0       85
# 37                      0        0          0                0       28
# 27                     25       25         50               25      193
# 45                      0        0          0                0       26
# 23                     32       32         50               32      750
#
#          MAIN_ENTRANCE_LONG  MAIN_ENTRANCE_LAT  GLOBALID  \
# OBJECTID
# 25              -122.385970          37.769630       NaN
# 37              -122.435174          37.724973       NaN
# 27              -122.405636          37.775342       NaN
# 45              -122.466414          37.782317       NaN
# 23              -122.407448          37.787679       NaN
#
#                                                    point  ADDRESS_NUMBER
# OBJECTID
# 25        POINT (-122.38595679041838 37.769625053788175)             601
# 37        POINT (-122.43516088822831 37.724967721057546)              20
# 27        POINT (-122.40562295281546 37.775337305753055)             415
# 45         POINT (-122.46640038092947 37.78231182661906)             324
# 23         POINT (-122.40743473111398 37.78767396886938)             333
#
# [5 rows x 35 columns]

# %%
# Out:
# Index(['Location Id', 'Business Account Number', 'Ownership Name', 'DBA Name',
#        'Street Address', 'City', 'State', 'Source Zipcode',
#        'Business Start Date', 'Business End Date', 'Location Start Date',
#        'Location End Date', 'Mail Address', 'Mail City', 'Mail Zipcode',
#        'Mail State', 'NAICS Code', 'NAICS Code Description', 'Parking Tax',
#        'Transient Occupancy Tax', 'LIC Code', 'LIC Code Description',
#        'Supervisor District', 'Neighborhoods - Analysis Boundaries',
#        'Business Corridor', 'Business Location', 'Address Number', 'OSP_ID',
#        'FACILITY_NAME', 'STREET_ADDRESS', 'LOCATION', 'PHONE',
#        'PM_DISTRICT_ID', 'AREA_TYPE', 'BLOCKFACE_ID', 'STREET_SEG_CTRLN_ID',
#        'FACILITY_TYPE', 'OWNER', 'SENSOR_FLAG', 'METER_FLAG', 'DATA_FEED_FLAG',
#        'SERVICES', 'WEB_SITE', 'VEH_ENTRY_LANES', 'MC_ENTRY_LANES',
#        'VEH_EXIT_LANES', 'MC_EXIT_LANES', 'SYSTEM', 'HI_VOL_DISC_FLAG',
#        'VALIDATION_PGM', 'SP_EVT_RATES', 'ACTIVATION_FEE', 'CARD_REPLACE_FEE',
#        'LATE_FEE', 'REOPEN_FEE', 'NO_KEY_VALET_FEE', 'CAPACITY',
#        'MAIN_ENTRANCE_LONG', 'MAIN_ENTRANCE_LAT', 'GLOBALID', 'point',
#        'ADDRESS_NUMBER'],
#       dtype='object')

# %%
# Out:
# <class 'str'>
# <class 'str'>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-b2f0d0b79b35> in <module>
#       1 from functools import reduce # python 3 only
# ----> 2 reduce(np.intersect1d, [df1['Street Address'].str, df2['STREET_ADDRESS'].str])
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in intersect1d(ar1, ar2, assume_unique, return_indices)
#     414         aux = aux[aux_sort_indices]
#     415     else:
# --> 416         aux.sort()
#     417
#     418     mask = aux[1:] == aux[:-1]
#
# TypeError: '<' not supported between instances of 'StringMethods' and 'StringMethods'

# %%
df3 = pd.read_csv('./SF_Films.csv')

# %%
df3.head()
# Out:
#   Title  Release Year                              Locations Fun Facts  \
# 0   180          2011      Epic Roasthouse (399 Embarcadero)       NaN
# 1   180          2011  Mason & California Streets (Nob Hill)       NaN
# 2   180          2011                    Justin Herman Plaza       NaN
# 3   180          2011                200 block Market Street       NaN
# 4   180          2011                              City Hall       NaN
#
#   Production Company Distributor  Director  \
# 0        SPI Cinemas         NaN  Jayendra
# 1        SPI Cinemas         NaN  Jayendra
# 2        SPI Cinemas         NaN  Jayendra
# 3        SPI Cinemas         NaN  Jayendra
# 4        SPI Cinemas         NaN  Jayendra
#
#                                               Writer   Actor 1       Actor 2  \
# 0  Umarji Anuradha, Jayendra, Aarthi Sriram, & Suba   Siddarth  Nithya Menon
# 1  Umarji Anuradha, Jayendra, Aarthi Sriram, & Suba   Siddarth  Nithya Menon
# 2  Umarji Anuradha, Jayendra, Aarthi Sriram, & Suba   Siddarth  Nithya Menon
# 3  Umarji Anuradha, Jayendra, Aarthi Sriram, & Suba   Siddarth  Nithya Menon
# 4  Umarji Anuradha, Jayendra, Aarthi Sriram, & Suba   Siddarth  Nithya Menon
#
#        Actor 3
# 0  Priya Anand
# 1  Priya Anand
# 2  Priya Anand
# 3  Priya Anand
# 4  Priya Anand
